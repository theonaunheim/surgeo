# %%
import surgeo

# %%
surgeo.VERSION
# Out:
# '2010.1.1'

# %%
dir(surgeo)
# Out:
# ['GeocodeModel',
#  'SurgeoModel',
#  'SurnameModel',
#  'VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'models']

# %%
s = surgeo.SurnameModel()


dir(s)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-cb302330820b> in <module>
# ----> 1 s = surgeo.SurnameModel()
#       2
#       3
#       4 dir(s)
#
# ~\development\surgeo\surgeo\models\surname_model.py in __init__(self)
#       5
#       6     def __init__(self):
# ----> 7         super().__init__()
#       8
#
# ~\development\surgeo\surgeo\models\base_model.py in __init__(self)
#      16             self._package_root /
#      17             'data' /
# ---> 18             'surname_2010.csv'
#      19         )
#      20
#
# ...
